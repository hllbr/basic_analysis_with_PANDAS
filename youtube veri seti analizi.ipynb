# %%
import pandas as pd

# %%
dataset = pd.read_csv("two/USvideos.csv")

# %%
dataset
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 23357  pH7VfJDq7f4      18.12.03
# 23358  hV-yHbbrKRA      18.12.03
# 23359  CwKp6Xhy3_4      18.12.03
# 23360  vQiiNGllGQo      18.12.03
# 23361  2afSbqlp5HU      18.12.03
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# ...

# %%
dataset.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
#bu head içerisine sadece 5 yada n = 5 yazarakta aynı sonucu alabiliriz.Head() boşsa ilk 5 veriyi verir bize

# %%
dataset.drop(["thumbnail_link","video_id","trending_date","publish_time","thumbnail_link","comments_disabled","ratings_disabled","video_error_or_removed"],axis = 1,inplace = True)

# %%
dataset
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
len(dataset.index)#satır
# Out:
# 23362

# %%
len(dataset.columns)#sütun
# Out:
# 9

# %%
dataset["likes"]
# Out:
# 0         57527
# 1         97185
# 2        146033
# 3         10172
# 4        132235
#           ...
# 23357     14826
# 23358     13600
# 23359      7504
# 23360     12448
# 23361      7408
# Name: likes, Length: 23362, dtype: int64

# %%
dataset["likes"].mean()
# Out:
# 45085.35972947522

# %%
dataset["dislikes"]
# Out:
# 0        2966
# 1        6146
# 2        5339
# 3         666
# 4        1989
#          ...
# 23357     279
# 23358     329
# 23359     584
# 23360     146
# 23361    1344
# Name: dislikes, Length: 23362, dtype: int64

# %%
dataset["dislikes"].mean()
# Out:
# 2809.7094426847016

# %%
dataset["views"].max()
# Out:
# 149376127

# %%
dataset[dataset["views"] == dataset["views"].max()]
# Out:
#                                                   title      channel_title  \
# 6181  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
#
#       category_id                                               tags  \
# 6181           24  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...
#
#           views    likes  dislikes  comment_count  \
# 6181  149376127  3093544   1643059         810698
#
#                                             description
# 6181  YouTube Rewind 2017. Celebrating the videos, p...

# %%
dataset[dataset["views"] == dataset["views"].max()]["title"]
# Out:
# 6181    YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# Name: title, dtype: object

# %%
dataset[dataset["views"] == dataset["views"].max()]["title"].iloc[0]
# Out:
# 'YouTube Rewind: The Shape of 2017 | #YouTubeRewind'

# %%
dataset["views"].min()
# Out:
# 549

# %%
dataset[dataset["views"] == dataset["views"].min()]
# Out:
#                                                   title channel_title  \
# 14335  1 dead, others injured after Ky. school shooting         Newsy
#
#        category_id                                               tags  views  \
# 14335           25  shooting|"kentucky"|"breaking news"|"u.s. news...    549
#
#        likes  dislikes  comment_count  \
# 14335      9         0              5
#
#                                              description
# 14335  Kentucky Gov. Matt Bevin confirmed there was a...

# %%
dataset[dataset["views"] == dataset["views"].min()]["title"]
# Out:
# 14335    1 dead, others injured after Ky. school shooting
# Name: title, dtype: object

# %%
dataset[dataset["views"] == dataset["views"].min()]["title"].iloc[0]
# Out:
# '1 dead, others injured after Ky. school shooting'

# %%
dataset.groupby("category_id").mean()
# Out:
#                     views          likes      dislikes  comment_count
# category_id
# 1            2.049144e+06   47593.034743   2027.794562    6003.651813
# 2            1.412712e+06    9989.032353    613.911765    1730.438235
# 10           2.555946e+06  120687.778075   4003.628045   10383.559418
# 15           5.538671e+05   16425.096121    389.399663    2474.376054
# 17           1.310862e+06   30259.176898   2066.235057    3256.199515
# 19           8.613965e+05    9193.538168    839.041985    1833.011450
# 20           1.025884e+06   36906.295082   2456.649180    7578.383607
# 22           1.075469e+06   36033.730117   1829.890244    4491.865854
# 23           1.162698e+06   55259.666330   1771.822548    5432.868554
# 24           1.354847e+06   38033.904071   5283.989217    7178.388176
# 25           3.327692e+05    4034.712638   1192.622968    1523.749869
# 26           6.562508e+05   26010.616689    894.296743    4992.165997
# ...

# %%
dataset.groupby("category_id").mean()["comment_count"]
# Out:
# category_id
# 1       6003.651813
# 2       1730.438235
# 10     10383.559418
# 15      2474.376054
# 17      3256.199515
# 19      1833.011450
# 20      7578.383607
# 22      4491.865854
# 23      5432.868554
# 24      7178.388176
# 25      1523.749869
# 26      4992.165997
# 27      2143.574850
# 28      3350.945159
# 29    100071.562500
# 43      1340.375000
# Name: comment_count, dtype: float64

# %%
dataset.groupby("category_id").mean()[["comment_count"]]
# Out:
#              comment_count
# category_id
# 1              6003.651813
# 2              1730.438235
# 10            10383.559418
# 15             2474.376054
# 17             3256.199515
# 19             1833.011450
# 20             7578.383607
# 22             4491.865854
# 23             5432.868554
# 24             7178.388176
# 25             1523.749869
# 26             4992.165997
# 27             2143.574850
# 28             3350.945159
# 29           100071.562500
# 43             1340.375000

# %%
#[] comment_count ikinci bir parantezleme ile kaplanırsa bize dataframe veriyor.

# %%
dataset["category_id"].value_counts()
# Out:
# 24    5379
# 10    3366
# 26    2241
# 23    1978
# 25    1907
# 22    1886
# 28    1477
# 1     1324
# 17    1238
# 27    1002
# 15     593
# 2      340
# 20     305
# 19     262
# 29      48
# 43      16
# Name: category_id, dtype: int64

# %%
dataset["title"].apply(len)
# Out:
# 0        34
# 1        62
# 2        53
# 3        32
# 4        24
#          ..
# 23357    19
# 23358    29
# 23359    24
# 23360    45
# 23361    42
# Name: title, Length: 23362, dtype: int64

# %%
dataset["title_length"] = dataset["title"].apply(len)

# %%
dataset
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
def count_Tag(tag):
    taglist =tag.split("|")
    return len(taglist)
dataset["tags"].apply(count_Tag)
# Out:
# 0         1
# 1         4
# 2        23
# 3        27
# 4        14
#          ..
# 23357     4
# 23358    31
# 23359    25
# 23360    11
# 23361    13
# Name: tags, Length: 23362, dtype: int64

# %%
dataset["CountLength"] = dataset["tags"].apply(count_Tag)

# %%
dataset
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
dataset["likes"].iteritems()

# %%
list(dataset["likes"].iteritems())
# Out:
# [(0, 57527),
#  (1, 97185),
#  (2, 146033),
#  (3, 10172),
#  (4, 132235),
#  (5, 9763),
#  (6, 15993),
#  (7, 23663),
#  (8, 3543),
#  (9, 12654),
#  (10, 655),
#  (11, 1576),
#  (12, 114188),
#  (13, 7848),
#  (14, 7473),
#  (15, 9419),
#  (16, 8011),
#  (17, 5398),
#  (18, 11963),
#  (19, 8421),
#  (20, 9586),
#  (21, 3585),
#  (22, 11758),
#  (23, 1707),
#  (24, 4884),
#  (25, 8676),
#  (26, 4687),
#  (27, 9033),
#  (28, 156),
#  (29, 715),
#  (30, 4035),
#  (31, 119),
#  (32, 787419),
#  (33, 3781),
#  (34, 1661),
#  (35, 2486),
#  (36, 7515),
#  (37, 1318),
#  (38, 38397),
#  (39, 6927),
#  (40, 5389),
#  (41, 308),
#  (42, 7),
#  (43, 15186),
#  (44, 4451),
#  (45, 33505),
#  (46, 3417),
#  (47, 2017),
#  (48, 35),
#  (49, 45406),
#  (50, 99086),
#  (51, 205),
#  (52, 15397),
#  (53, 190083),
#  (54, 7250),
#  (55, 16116),
#  (56, 5734),
#  (57, 21),
#  (58, 89),
#  (59, 8209),
#  (60, 10237),
#  (61, 52),
#  (62, 26917),
#  (63, 115795),
#  (64, 493),
#  (65, 8231),
# ...

# %%
likesList = []
for key,value in list(dataset["likes"].iteritems()):
    likesList.append(value)
print(likesList)
# Out:
# [57527, 97185, 146033, 10172, 132235, 9763, 15993, 23663, 3543, 12654, 655, 1576, 114188, 7848, 7473, 9419, 8011, 5398, 11963, 8421, 9586, 3585, 11758, 1707, 4884, 8676, 4687, 9033, 156, 715, 4035, 119, 787419, 3781, 1661, 2486, 7515, 1318, 38397, 6927, 5389, 308, 7, 15186, 4451, 33505, 3417, 2017, 35, 45406, 99086, 205, 15397, 190083, 7250, 16116, 5734, 21, 89, 8209, 10237, 52, 26917, 115795, 493, 8231, 115426, 120876, 203, 55681, 1634124, 2233, 2978, 1550, 18603, 2429, 1896, 37669, 15504, 355, 23296, 8133, 2323, 67, 3571, 6271, 16430, 439, 34839, 82320, 438, 72593, 2282, 98804, 58967, 8599, 40195, 16396, 202676, 14338, 43875, 
# ...

# %%
def likesDislikesRatio(likes,dislikes):
    likeList = []
    for key,value in list(likes.iteritems()):
        likeList.append(value)
    dislikeList = []
    for key,value in list(dislikes.iteritems()):
        dislikeList.append(value)
        
    print(len(likeList),len(dislikeList))
likesDislikesRatio(dataset["likes"],dataset["dislikes"])
# Out:
# 23362 23362

# %%
def likesDislikesRatio(likes,dislikes):
    likeList = []
    for key,value in list(likes.iteritems()):
        likeList.append(value)
    dislikeList = []
    for key,value in list(dislikes.iteritems()):
        dislikeList.append(value)
        
    likesdislike = list(zip(likeList,dislikeList))
    print(likesdislike)
likesDislikesRatio(dataset["likes"],dataset["dislikes"])
# Out:
# [(57527, 2966), (97185, 6146), (146033, 5339), (10172, 666), (132235, 1989), (9763, 511), (15993, 2445), (23663, 778), (3543, 119), (12654, 1363), (655, 25), (1576, 303), (114188, 1333), (7848, 1171), (7473, 246), (9419, 52), (8011, 638), (5398, 53), (11963, 36), (8421, 191), (9586, 75), (3585, 138), (11758, 89), (1707, 578), (4884, 52), (8676, 193), (4687, 41), (9033, 224), (156, 36), (715, 238), (4035, 495), (119, 69), (787419, 43420), (3781, 84), (1661, 70), (2486, 184), (7515, 792), (1318, 24), (38397, 1387), (6927, 161), (5389, 106), (308, 26), (7, 5), (15186, 15448), (4451, 1772), (33505, 1660), (3417, 33), (2017, 2425), (35, 18), (45406, 2842), (99086, 1339), (205, 6), (15397, 838), (190083, 15015), (7250, 217), (16116, 236), (5734, 106), (21, 8), (89, 8), (8209, 344), (10237, 377), (52, 13), (26917, 1979), (115795, 3055), (493, 54), (8231, 413), (115426, 1110), (120876, 8279), (203, 6), (55681, 10247), (1634124, 21082), (2233, 187), (2978, 147), (1550, 109), (18603, 585), (24
# ...

# %%
def likesDislikesRatio(likes,dislikes):
    likeList = []
    for key,value in list(likes.iteritems()):
        likeList.append(value)
    dislikeList = []
    for key,value in list(dislikes.iteritems()):
        dislikeList.append(value)
        
    likesdislike = list(zip(likeList,dislikeList))
    ratio = []
    for like,dislike in likesdislike:
        if (like + dislike) == 0:
            ratio.append(0)
        else:
            ratio.append(like/(like+ dislike))
    print(ratio)
        
    return ratio
likesDislikesRatio(dataset["likes"],dataset["dislikes"])
# Out:
# [0.9509695336650521, 0.9405212375763323, 0.9647292762201728, 0.938549547887064, 0.9851814876624151, 0.9502627992992019, 0.8673934266189391, 0.9681682418886297, 0.9675040961223376, 0.9027609331526004, 0.9632352941176471, 0.8387440127727515, 0.988460972463881, 0.8701629892449274, 0.9681305868635833, 0.9945095554851653, 0.9262342467337265, 0.9902770133920381, 0.996999749979165, 0.977821644217371, 0.992236828485664, 0.9629331184528606, 0.9924875495906137, 0.7470459518599563, 0.9894651539708266, 0.978238809335889, 0.9913282571912013, 0.9758020957113536, 0.8125, 0.7502623294858342, 0.890728476821192, 0.6329787234042553, 0.9477395740931757, 0.9782664941785252, 0.9595609474292317, 0.9310861423220974, 0.90465872156013, 0.9821162444113264, 0.9651367383872914, 0.977285553047404, 0.9807097361237489, 0.9221556886227545, 0.5833333333333334, 0.49572370568649216, 0.7152498794793508, 0.9527939712782596, 0.9904347826086957, 0.4540747411076092, 0.660377358490566, 0.9410960039794396, 0.9866666666666667,
# ...

# %%
def likesDislikesRatio(likes,dislikes):
    likeList = []
    for key,value in list(likes.iteritems()):
        likeList.append(value)
    dislikeList = []
    for key,value in list(dislikes.iteritems()):
        dislikeList.append(value)
        
    likesdislike = list(zip(likeList,dislikeList))
    ratio = []
    for like,dislike in likesdislike:
        if (like + dislike) == 0:
            ratio.append(0)
        else:
            ratio.append(like/(like+ dislike))
    
        
    return ratio
dataset["likes_dislikes"] = likesDislikesRatio(dataset["likes"],dataset["dislikes"])

# %%
dataset
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
dataset.sort_values("likes_dislikes")#küçükten büyüğe sıralama
# Out:
#                                                    title  \
# 4682   Arizona State introductory press conference of...
# 16324         Slooh's Blue Supermoon Total Lunar Eclipse
# 11385  Mariah Carey - Live At Dick Clark's New Year's...
# 10142  PART 1 | Gwen Stefani with Blake Shelton | Ins...
# 16381                                    To Our Daughter
# ...                                                  ...
# 19257  Jamie Foxx Awkward Interview SportsCenter Mich...
# 16296  Man pouring drinks (Jagerbomb shots) with his ...
# 14267                 Introducing #AerieREAL Role Models
# 9351                                  Christmas Day 2000
# 1139            #StarOnFox Exclusive Clip for TheYBF.com
#
#                   channel_title  category_id  \
# 4682            Pac-12 Networks           17
# 16324                     Slooh           28
# 11385            mariahxlambily           10
# 10142  Famous Celebrities Snaps            2
# 16381              Kylie Jenner           22
# ...

# %%
dataset.sort_values("likes_dislikes",ascending=False)#büyükten küçük olana doğru
# Out:
#                                                    title        channel_title  \
# 8694                                  Christmas Day 2000             vnbreyes
# 16100                                  Magic Highway USA         Joshua Levin
# 921             #StarOnFox Exclusive Clip for TheYBF.com             YBF Chic
# 16369  First Responders Arrive To The Collapsed Floor...         9-1-1 on FOX
# 147    Improvising in the style of different classica...            Nahre Sol
# ...                                                  ...                  ...
# 15575       Official XFL Announcement with Vince McMahon  Alpha Entertainment
# 4752                      The New Snapchat in 60 Seconds             Snapchat
# 16590                                    To Our Daughter         Kylie Jenner
# 15510   Carolyn's RV Life Spots A Fluffy Kitty In Blythe      Caravan Carolyn
# 22020         GET READY WITH ME | Halo Beauty Launch Day                 Tati
#
# ...

# %%
dataset.sort_values("likes_dislikes",ascending=False,inplace=True)

# %%
dataset
# Out:
#                                                    title        channel_title  \
# 8694                                  Christmas Day 2000             vnbreyes
# 16100                                  Magic Highway USA         Joshua Levin
# 921             #StarOnFox Exclusive Clip for TheYBF.com             YBF Chic
# 16369  First Responders Arrive To The Collapsed Floor...         9-1-1 on FOX
# 147    Improvising in the style of different classica...            Nahre Sol
# ...                                                  ...                  ...
# 15575       Official XFL Announcement with Vince McMahon  Alpha Entertainment
# 4752                      The New Snapchat in 60 Seconds             Snapchat
# 16590                                    To Our Daughter         Kylie Jenner
# 15510   Carolyn's RV Life Spots A Fluffy Kitty In Blythe      Caravan Carolyn
# 22020         GET READY WITH ME | Halo Beauty Launch Day                 Tati
#
# ...

# %%
newdataset = dataset.drop(["likes_dislikes","channel_title"],axis=1)

# %%
newdataset
# Out:
#                                                    title  category_id  \
# 8694                                  Christmas Day 2000           17
# 16100                                  Magic Highway USA           28
# 921             #StarOnFox Exclusive Clip for TheYBF.com           24
# 16369  First Responders Arrive To The Collapsed Floor...           24
# 147    Improvising in the style of different classica...           10
# ...                                                  ...          ...
# 15575       Official XFL Announcement with Vince McMahon           17
# 4752                      The New Snapchat in 60 Seconds           10
# 16590                                    To Our Daughter           22
# 15510   Carolyn's RV Life Spots A Fluffy Kitty In Blythe           22
# 22020         GET READY WITH ME | Halo Beauty Launch Day           26
#
#                                                     tags     views  likes  \
# ...

# %%
newdataset.to_csv("UsVideosNew.csv")

# %%
newdataset.to_csv("UsVideosNew1.csv",index=False)

# %%
len(newdataset)
# Out:
# 23362
